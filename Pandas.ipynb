# %% [markdown]
# # Introducción a pandas
# ¿Qué es?
# - Es una biblioteca de Python para análisis de datos.
# - Sirve para leer y escribir datos.
# - Es excelente para limpiar y preparar datos
# - Permite analizar y manipular datos.

# %%
#intalar pandas
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\gerar\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
#importar pandas para explorar datos
import pandas as pd

# %%
#Cargar el archivo csv
df = pd.read_csv('03_IBD_GTstudentproject_train.csv')

# %%
# Head muestra las primeras 5 filas del DataFrame
df.head(2)
# Out:
#    SamplingOperations_code   IBD   IBD_EQR IBD_EQR_Status
# 0       S04319000_20130724   5.2  0.256098            Bad
# 1       S06172100_20080716   6.1  0.298246            Bad
# 2       S03255920_20120802   3.7  0.157895            Bad
# 3       S04064720_20150710   4.9  0.228070            Bad
# 4       S05001500_20080726   5.3  0.251462            Bad
# 5       S04417048_20220803  13.0  0.701754       Moderate
# 6       S04026066_20220816  11.2  0.596491       Moderate
# 7       S02042348_20210810  13.5  0.730994       Moderate
# 8       S04454025_20200629  13.0  0.571429       Moderate
# 9       S04023400_20150605  10.3  0.543860           Poor
# 10      S02115772_20170824  10.3  0.543860           Poor
# 11      S05025800_20150623  10.1  0.532164           Poor
# 12      S02100603_20180828  12.5  0.535714           Poor
# 13      S02081030_20180824   4.7  0.216374            Bad
# 14      S06041000_20191002   8.4  0.242857            Bad
# ...

# %%
#Agregue esto
#muestra los últimos 5
df.tail()

# %%
# Muestra un resumen completo de la estructura del DataFrame
#Aquí explicar que información se puede recuperar o analizar.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43783 entries, 0 to 43782
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   SamplingOperations_code  43783 non-null  object
#  1   IBD                      43783 non-null  float64
#  2   IBD_EQR                  43783 non-null  float64
#  3   IBD_EQR_Status           43783 non-null  object
# dtypes: float64(2), object(2)
# memory usage: 1.3+ MB

# %%
# Muestra una lista de todos los nombres de las columnas
df.columns
# Out:
# Index(['SamplingOperations_code', 'IBD', 'IBD_EQR', 'IBD_EQR_Status'], dtype='object')

# %%
# Describe las columnas NUMÉRICAS (conteo, media, desviación estándar, min, max, etc.)
# mencionar que són datos estadísticos
df.describe()
# Out:
#                 IBD       IBD_EQR
# count  43783.000000  43783.000000
# mean      15.370151      0.803836
# std        2.802306      0.151688
# min        1.000000      0.000000
# 25%       13.700000      0.719298
# 50%       15.200000      0.818713
# 75%       17.200000      0.914286
# max       20.000000      1.000000
