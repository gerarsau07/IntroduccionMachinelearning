# %% [markdown]
# # Predicción de salario

# %% [markdown]
# ### Usaremos salarios_tecnologia_mexico.csv para realizar este ejercicio
# * Primero graficar el csv para su conpresion, que tipo de variables afectan a la prediccion.
# * Realizar la predicción con algun modelo de apredizaje supervizad

# %% [markdown]
# ## Pistas:
# * Encontra las variables que afectan nuestra prediccion
# * X = pd.get_dummies(X, drop_first=True) (para que el modelo pueda entender las palabras)
